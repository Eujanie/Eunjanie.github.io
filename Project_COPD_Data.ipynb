# %% [markdown]
# # **STAT 200 Project (100 points)**
#
# #### **WRITE YOUR NAME HERE**

# %% [markdown]
# ---
#
# <br>
#
# For your project, you must analyze data from the [COPDGene study](http://www.copdgene.org/) using the concepts covered in this course. Please follow the directions below carefully:
#
# - <font color=red>Tasks</font> indicated in red must be completed to receive credit
# - Include all code for your work
# - Comment all code using the `#`. This is a must!
# - Include markdown cells with written answers explaining your work when prompted
# - **NOTE: Your completed project must be submitted to Canvas as a .ipynb file by the assigned due date**

# %% [markdown]
# <br>
#
# ---
#
# <br>

# %% [markdown]
# ## Data
#
# Data for the project is available [here](https://raw.githubusercontent.com/khasenst/datasets_teaching/main/copd_data_project.csv). A data dictionary describing the meaning of each of the variables in the dataset is available in the Project module in Canvas.

# %% [markdown]
# <br>
#
# ---
#
# <br>

# %% [markdown]
# ## Introduction
#
# Chronic obstructive pulmonary disease (COPD) affects over 16 million Americans and is the fourth leading cause of death in the United States behind heart disease, cancer, and accidental death. While COPD can result from various toxic inhalations or asthma, it is most commonly associated with cigarette smoking.
#
# <br>
#
# COPD severity is typically measured by a device called a spirometer. Patients forcefully exhale into the device and the volume of air exhaled is used as a measure for the severity of disease (less air exhaled $\Rightarrow$ worse disease). Data collected by the COPDGene research group includes spirometry data on thousands of research participants.
#
# <br>
#
# Spirometry measures in the dataset:
# * The forced expiratory volume (`FEV1`) is the volume of air exhaled in 1 second
# * The forced vital capacity (`FVC`) is the total volume of air exhaled after a full breath
# * `FEV1_FVC_ratio` is the ratio between `FEV1` and `FVC` (smaller $\Rightarrow$ worse disease)
# * `FEV1_phase2` is the `FEV1` of research participants 5 years later
#
# <br>
#
# You overall task in this project is to analyze the relationship between FEV1 at follow-up `FEV1_phase2` and other variables in the dataset. The project has been organized into a series of tasks to assist you with your analysis organization.

# %% [markdown]
# <br>
#
# ---
#
# <br>

# %% [markdown]
# ####<font color=red>Organized</font> (5 points)
# * Answers should be organized in the following format for organization and readability
#
# <br>
#
# ```
# # 1.
# This will be the code block to answer the first part of a task
# ```
#
# 1. This will be the text answer/explanation (if prompted) for the first task
#
# ```
# # 2.
# This will be the code block to answer the second part of a task in a separate code cell
# ```
#
# 2. This will be the text answer/explanation (if prompted) for the second task
#
# <br>
#
# Continue this format for the remaining subtasks

# %% [markdown]
# <br>
#
# ---
#
# <br>

# %% [markdown]
# ####<font color=red>Task 1</font> (5 points)
#
# 1. Load the COPDGene dataset and show the first few lines.
# 2. Remove the NAs from the dataset and store as `dat1`. How many rows does `dat1` contain? Answer in a complete sentence.
# 3. Select all rows in the dataset where `FEV1_phase2` is `NA` and store as `dat2`. How many rows does `dat2` contain? Answer in a complete sentence.

# %%
#1.1
dat<- read.csv("https://raw.githubusercontent.com/khasenst/datasets_teaching/main/copd_data_project.csv")
head(dat)
# Out:
#   sid    visit_year visit_date visit_age gender race  height_cm weight_kg sysBP
# 1 10005Q 2008       1/15/2008  54.5      Female White 159.9      73.0     130
# 2 10006S 2008       1/15/2008  62.3      Female White 162.6      86.0     170
# 3 10010J 2008       1/15/2008  65.9      Female White 162.1      62.8      96
# 4 10015T 2008       2/15/2008  59.6      Male   White 182.9     110.0     142
# 5 10017X 2008       6/15/2008  67.5      Male   White 179.1      83.0     106
# 6 10022Q 2008       2/15/2008  69.8      Female White 158.8      78.0     122
#   diasBP ⋯ total_lung_capacity pct_emphysema functional_residual_capacity
# 1 80     ⋯ 5.6636               0.926851      2.4766
# 2 80     ⋯ 5.2325              14.005900     -1.0000
# 3 63     ⋯ 5.1960               1.683760      3.8993
# 4 88     ⋯ 6.3971               9.330450     -1.0000
# 5 72     ⋯ 7.8935              36.262400      4.1043
# 6 78     ⋯ 5.1016              30.484400     -1.0000
#   pct_gastrapping insp_meanatt exp_meanatt FEV1_FVC_ratio FEV1  FVC
# 1  6.80077        -830.343     -650.526    0.77           2.921 3.805
# 2 -1.00000        -841.880       -1.000    0.43           1.288 3.022
# 3 41.34930        -833.429     -789.595    0.53           1.008 1.909
# 4 -1.00000        -841.315       -1.000    0.51           1.906 3.732
# 5 46.17690        -887.947     -792.397    0.57           2.748 4.827
# 6 -1.00000        -865.608       -1.000    0.53           1.076 2.047
#   FEV1_phase2
# 1 2.622
# 2    NA
# 3 1.087
# 4 2.002
# 5 2.178
# 6 0.924

# %%
#1.2
dat1 <- na.omit(dat)
nrow(dat1)
# Out:
# [1] 4000

# %% [markdown]
# dat1 has 4000rows.

# %%
#1.3
dat2 <- dat[is.na(dat$FEV1_phase2),]
nrow(dat2)
# Out:
# [1] 1747

# %% [markdown]
# dat2 has 1747 rows.

# %% [markdown]
# <br>
#
# ---
#
# <br>

# %% [markdown]
# ####<font color=red>Task 2</font> (10 points)
#
# 1. From `dat1`, plot the histogram of `FEV1`
# 2. Calculate the percentage of `FEV1` values within one standard deviation of its mean. Answer in a complete sentence.
# 3. Calculate the percentage of `FEV1` values within 2 standard deviations of its mean. Answer in a complete sentence.
# 4. Use your answers from 2.1-2.3 to determine if the FEV1 variable is approximately normally distributed.

# %%
#2.1
hist(dat1$FEV1)
# Out:
# Plot with title “Histogram of dat1$FEV1”

# %%
#2.2
length(dat1$FEV1[dat1$FEV1 > (mean(dat1$FEV1)-1*sd(dat1$FEV1)) & dat1$FEV1 < (mean(dat1$FEV1)+1*sd(dat1$FEV1))])/length(dat1$FEV1)*100

#2.3
length(dat1$FEV1[dat1$FEV1 > (mean(dat1$FEV1)-2*sd(dat1$FEV1)) & dat1$FEV1 < (mean(dat1$FEV1)+2*sd(dat1$FEV1))])/length(dat1$FEV1)*100

#2.4
# 2-1에서 histgram은 정규분포 모양을 보인다.
# 그리고 2-2에서 약 68%의 값들이 평균에서 양쪽으로 1 표준편차 범위(μ±σ)에 존재한다. 
# 또한 2-3에서 약 95%의 값들이 평균에서 양쪽으로 2 표준편차 범위(μ±2σ)에 존재한다.
# 따라서 FEV1은 정규분포를 따른다고 할 수 있다.
# Out:
# [1] 67.575
# [1] 96.75

# %% [markdown]
# 2.2 67.575% of FEV1 values is in one standard deviation of its mean.

# %% [markdown]
# 2.3 96.75% of FEV1 values is in two standard deviation of its mean.

# %% [markdown]
# 2.4 According to 2.1 histogram it follows a normal distribution.
# and 68% of FEV1 values ​​in 2.2 exists in the range of 1 standard deviation. Also, 95% of FEV1 values exists in the range of 2 standard deviations (2.3). Therefore,FEV1 follows a normal distribution.

# %% [markdown]
# <br>
#
# ---
#
# <br>

# %% [markdown]
# ####<font color=red>Task 3</font> (10 points)
#
# 1. From `dat1`, find two other numeric variables and plot their histograms.
# 2. Describe the histogram of the FIRST variable you chose.
#     * Range, standard deviation, skewness or symmetry, mean, normally distributed, outlier observations etc.
#     * You may use R functions to help you answer and describe the distribution
#     * Answer in complete sentences in a paragraph
# 2. Describe the histogram of the SECOND variable you chose.
#     * Range, standard deviation, skewness or symmetry, mean, normally distributed, outlier observations etc.
#     * You may use R functions to help you answer and describe the distribution
#     * Answer in complete sentences in a paragraph

# %%
#3.2
hist(dat1$visit_age)


range(dat1$visit_age)
sd(dat1$visit_age)
median(dat1$visit_age)
mean(dat1$visit_age)
# Out:
# [1] 39 85
# [1] 8.611419
# [1] 59.4
# [1] 59.67142
# Plot with title “Histogram of dat1$visit_age”

# %% [markdown]
# 3.2 Range is between 39 and 85, standard deviation is about 8.61. Visit age of dat1 is almost symmetric since there is a little difference between median and mean. Both are almost same so symmetric and normally distributed. Mean is about 59.7.

# %%
#3.3
hist(dat1$pct_emphysema)

range(dat1$pct_emphysema)
sd(dat1$pct_emphysema)
median(dat1$pct_emphysema)
mean(dat1$pct_emphysema)
# Out:
# [1] -1.0000 56.0577
# [1] 7.920193
# [1] 1.168175
# [1] 4.218915
# Plot with title “Histogram of dat1$pct_emphysema”

# %% [markdown]
# 3.3 About the histogram of percentage of emphysema the range is between -1 and 56.1. The standard deviation is 7.92 and right skewed. Since mean> median and most data falls to the right as histogram showing up. Mean is about 4.22. The outlier exists for high percentage of emphysema.

# %% [markdown]
# <br>
#
# ---
#
# <br>

# %% [markdown]
# ####<font color=red>Task 4</font> (10 points)
#
# 1. Using `dat1`, create a boxplot to visualize the relationship between `FEV_phase2` and `smoking_status`.
# 2. Based on the boxplot, which group tends to have better breathing capacity?
# 3. Select rows in `dat1` corresponding to a `smoking_status` of `Current smoker` or `Former smoker`. Create a 95% confidence interval to determine if average FEV1 is different between current or former smokers. Explain your answer in complete sentences.

# %%
#4.1
boxplot(FEV1_phase2 ~ factor(smoking_status), data = dat1) 
#4.2 Never smoked 집단이 breathing capacity가 좋아 보인다.
# Out:
# plot without title

# %% [markdown]
# 4.2 The group of Never smoked has better breathing capacity.

# %%
#4.3 
dat4 <- dat1[dat1$smoking_status == "Current smoker",]
dat4.1 <- dat1[dat1$smoking_status == "Former smoker",]

mean.curr <- mean(dat4$FEV1)
mean.former <-mean(dat4.1$FEV1)

sd.curr <- sd(dat4$FEV1)
sd.former <- sd(dat4.1$FEV1)

n.curr <- length(dat4$FEV1)
n.former <- length(dat4.1$FEV1)

c(mean.curr - mean.former - 1.96*sqrt(sd.curr^2/n.curr + sd.former^2/n.former), 
    mean.curr - mean.former + 1.96*sqrt(sd.curr^2/n.curr + sd.former^2/n.former))
# Out:
# [1] 0.1093064 0.2176858

# %% [markdown]
# 4.3 As a result of obtaining a 96% confidence interval for the difference between the mean of the two groups, 0 is not included in the confidence interval.Therefore, it cannot be said that the two groups are the same.

# %% [markdown]
# <br>
#
# ---
#
# <br>

# %% [markdown]
# ####<font color=red>Task 5</font> (10 points)
#
# 1. Using `dat1`, create two more boxplots to visualize the relationship between `FEV1_phase2` and two other categorical variables.
# 2. For the first variable, use a 95% confidence interval to determine if the average `FEV1_phase2` is different between two categories.
# 3. For the second variable, use a 95% confidence interval to determine if the average `FEV1_phase2` in phase 2 is different between two categories.

# %%
head(dat1)
# Out:
#   sid    visit_year visit_date visit_age gender race
# 1 10005Q 2008       1/15/2008  54.5      Female White
# 3 10010J 2008       1/15/2008  65.9      Female White
# 4 10015T 2008       2/15/2008  59.6      Male   White
# 5 10017X 2008       6/15/2008  67.5      Male   White
# 6 10022Q 2008       2/15/2008  69.8      Female White
# 7 10025W 2008       2/15/2008  68.9      Male   Black or African American
#   height_cm weight_kg sysBP diasBP ⋯ total_lung_capacity pct_emphysema
# 1 159.9      73.0     130   80     ⋯ 5.6636               0.926851
# 3 162.1      62.8      96   63     ⋯ 5.1960               1.683760
# 4 182.9     110.0     142   88     ⋯ 6.3971               9.330450
# 5 179.1      83.0     106   72     ⋯ 7.8935              36.262400
# 6 158.8      78.0     122   78     ⋯ 5.1016              30.484400
# 7 168.9      51.0     120   60     ⋯ 6.4421              51.156200
#   functional_residual_capacity pct_gastrapping insp_meanatt exp_meanatt
# 1  2.4766                       6.80077        -830.343     -650.526
# 3  3.8993                      41.34930        -833.429     -789.595
# 4 -1.0000                      -1.00000        -841.315       -1.000
# 5  4.1043                      46.17690        -887.947     -792.397
# 6 -1.0000                      -1.00000        -865.608       -1.000
# 7 -1.0000                      -1.00000        -906.021       -1.000
#   FEV1_FVC_ratio FEV1  FVC   FEV1_phase2
# 1 0.77           2.921 3.805 2.622
# 3 0.53           1.008 1.909 1.087
# 4 0.51           1.906 3.732 2.002
# 5 0.57           2.748 4.827 2.178
# 6 0.53           1.076 2.047 0.924
# 7 0.27           0.718 2.697 0.596

# %%
#5.1
boxplot(dat1$FEV1_phase2 ~ dat1$gender)

boxplot(dat1$FEV1_phase2 ~ dat1$race)
# Out:
# plot without title
# plot without title

# %%
#5.2

mean.female <- mean(dat1$FEV1_phase2[dat1$gender == "Female"])
mean.man<- mean(dat1$FEV1_phase2[dat1$gender == "Male"])

sd.female <- sd(dat1$FEV1_phase2[dat1$gender == "Female"])
sd.man <- sd(dat1$FEV1_phase2[dat1$gender == "Male"])

n.female <- length(dat1$FEV1_phase2[dat1$gender == "Female"])
n.man <- length(dat1$FEV1_phase2[dat1$gender == "Male"])

c(mean.female - mean.man - 1.96*sqrt(sd.female^2/n.female + sd.man^2/n.man), 
  mean.female - mean.man + 1.96*sqrt(sd.female^2/n.female + sd.man^2/n.man))

#5.3
mean.black <- mean(dat1$FEV1_phase2[dat1$race == "Black or African American"])
mean.white <- mean(dat1$FEV1_phase2[dat1$race == "White"])

sd.black <- sd(dat1$FEV1_phase2[dat1$race == "Black or African American"])
sd.white <- sd(dat1$FEV1_phase2[dat1$race == "White"])

n.black = length(dat1$FEV1_phase2[dat1$race == "Black or African American"])
n.white = length(dat1$FEV1_phase2[dat1$race == "White"])

c(mean.black - mean.white - 1.96*sqrt(sd.black^2/n.black + sd.white^2/n.white), 
  mean.black - mean.white + 1.96*sqrt(sd.black^2/n.black + sd.white^2/n.white))
# Out:
# [1] -0.6918705 -0.5976890
# [1] -0.12504487 -0.01730543

# %% [markdown]
# As a result of calculating the 95% confidence interval for the difference in the mean value of FEV1_phase2 between two groups (male, female), 0 is not included.So the average value of FEV1_phase2 of the two groups cannot be said to be the same.

# %% [markdown]
# <br>
#
# ---
#
# <br>

# %% [markdown]
# ####<font color=red>Task 6</font> (20 points)
#
# 1. Using `dat1`, create a scatterplot visualizing the relationship between `FEV1_phase2` (y-axis) and `FEV1` (x-axis). Note that values that are -1 are missing observations. You may ignore this for this class.
# 2. What relationship do you observe based on the scatterplot?
# 3. Fit a simple linear regression model by regressing `FEV1_phase2` (Y) on `FEV1` (X). Summarize the regression.
# 4. Describe the $R^2$ of the regression in the context of its definition.
# 5. What is the slope and its interpretation in the context of `FEV1` and `FEV1_phase2`? Explain in complete sentences
# 6. What is the intercept and its interpretation in the context of `FEV1` and `FEV1_phase2`? Explain in complete sentences
# 7. Use a 95% confidence interval to determine if the slope is significantly less than 1. Explain what this means in terms of breathing health of the patients.

# %%
#6.1
 plot(dat1$FEV1, dat1$FEV1_phase2 ,
     xlab = "FEV1",
     ylab = "FEV1_phase2 ",
     main = "FEV1_phase2  vs FEV1")
# Out:
# Plot with title “FEV1_phase2  vs FEV1”

# %% [markdown]
# 6.2 As FEV1 goes up FEV1_phase2 is increased. Both values imply positive slope.

# %%
#6.3
fit <- lm(FEV1_phase2 ~ FEV1, data = dat1)
summary(fit)
# Out:
# Call:
# lm(formula = FEV1_phase2 ~ FEV1, data = dat1)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.5909 -0.1880 -0.0144  0.1609  4.3971
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 0.178336   0.016943   10.53   <2e-16 ***
# FEV1        0.840423   0.006859  122.53   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.3789 on 3998 degrees of freedom
# Multiple R-squared:  0.7897,	Adjusted R-squared:  0.7897
# F-statistic: 1.501e+04 on 1 and 3998 DF,  p-value: < 2.2e-16

# %% [markdown]
# 6.4 R^2=0.7897 and it close to 1. That is, this regression model is great fit. As the R^2 value is close to 1, we can expect the regression model is suitable. Now, R^2 = 0.7897, we can see that the regression model is somewhat suitable.

# %% [markdown]
# 6.5 Slope is about 0.8404. Every time FEV1 increases, FEV1_phase2 increases 0.84 times.

# %% [markdown]
# 6.6 The intercept is 0.178336.

# %%
#6.7
confint(fit)
# Out:
#             2.5 %     97.5 %
# (Intercept) 0.1451177 0.2115549
# FEV1        0.8269759 0.8538708

# %% [markdown]
# By the confidence interval, the interval is [0.827, 0.854]. This means that when FEV1 increases by one unit, FEV1_phase2 increases to a value between these intervals [0.827, 0.854]. Also the value increases to less than 1, it can be interpreted as having bad breathing capability.

# %% [markdown]
# <br>
#
# ---
#
# <br>

# %% [markdown]
# ####<font color=red>Task 7</font> (10 points)
#
# 1. Identify two other variables in `dat1` that you think would be related to breathing health, as measured by `FEV1_phase2`. Plot these variables using scatterplots (`FEV1` on Y axis, variable 1 or variable 2 on X axis). What do you observe? Explain in complete sentences.
# 2. Include these two variables (categorical or numeric), along with `FEV1`, in your regression from Task 6. Show the regression summary. Keep `FEV1_phase2` as Y.
# 3. Using 95% confidence intervals, are the slopes for the two variables you selected significantly different from 0? Explain and interpret in complete sentences.

# %%
#7.1
plot(FEV1 ~ pct_gastrapping, data = dat1)
# Out:
# plot without title

# %%
#7.2
fit <- lm(FEV1_phase2 ~ FEV1 + total_lung_capacity + pct_gastrapping, data = dat1)
summary(fit)
# Out:
# Call:
# lm(formula = FEV1_phase2 ~ FEV1 + total_lung_capacity + pct_gastrapping,
#     data = dat1)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.5760 -0.1813 -0.0165  0.1574  4.1633
#
# Coefficients:
#                       Estimate Std. Error t value Pr(>|t|)
# (Intercept)          0.2751017  0.0195474  14.074   <2e-16 ***
# FEV1                 0.7877636  0.0076502 102.973   <2e-16 ***
# total_lung_capacity  0.0255164  0.0025839   9.875   <2e-16 ***
# pct_gastrapping     -0.0062998  0.0004446 -14.170   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.3697 on 3996 degrees of freedom
# Multiple R-squared:  0.7999,	Adjusted R-squared:  0.7997
# F-statistic:  5325 on 3 and 3996 DF,  p-value: < 2.2e-16

# %%
#7.3
confint(fit)
# Out:
#                     2.5 %        97.5 %
# (Intercept)          0.236777816  0.313425591
# FEV1                 0.772765045  0.802762236
# total_lung_capacity  0.020450439  0.030582400
# pct_gastrapping     -0.007171373 -0.005428161

# %% [markdown]
# 7.3
# From the results above, the 95% confidence interval of the slope corresponds to the two selected variables, total_lung_capacity and pct_gastrapping. Both exist in [0.020450439,0.030582400] and [-0.007171373,-0.005428161],and zero is not included in the 95% confidence interval of the two variables.
# Therefore, it can be said that the slope of the two variables is significantly different from zero.

# %% [markdown]
# <br>
#
# ---
#
# <br>

# %% [markdown]
# ####<font color=red>Task 8</font> (5 points)
#
# 1. Using your regression model with three variables from Task 7, predict the `FEV1_phase2`.
# 2. Calculate the root mean squared error. Is this error large or small? Explain your answer.
#
#
# ```
# # Hint
# y <- dat1$FEV1_phase2
# y_predicted <- fitted(lm(...))
#
# # root mean squared error
# rmse <- sqrt(mean((y - y_predicted)^2))
# ```

# %%
#8.1
y <- dat1$FEV1_phase2 
y_predicted <- fitted(fit)

# %%
#8.2
n <- length(dat1$FEV1_phase2)
sqrt(sum((y - y_predicted)^2)/n)
# Out:
# [1] 0.3695431

# %% [markdown]
# 8.2 The value of MSE is small that means the regression model has good ability.

# %% [markdown]
# <br>
#
# ---
#
# <br>

# %% [markdown]
# ####<font color=red>Task 9</font> Group Task (15 points)
#
# 1. Using the statistical/machine learning concepts from class, build a model (preferably random forest) that best predicts the `FEV1_phase2` variable in the `dat2` dataframe.
# 2. Submit your predictions as a csv file in the format presented in the `copd_predictions.csv` file on Canvas.
#
# <br>
# <br>
#
# * The group with the lowest prediction error will receive 10 points extra credit on their overall project grade.
# * The group with the second lowest prediction error will receive 5 points extra credit on their overall project grade.
# * The group with the third lowest prediction error will receive 2 points extra credit on their overall project grade.

# %%
# 9.1

library(randomForest)


train <- dat[!is.na(dat$FEV1_phase2),]

forest_m <- randomForest(FEV1_phase2 ~ ., data=train)

forest_m   

prd_v <- predict(forest_m, newdata = dat2, type = 'class')
prd_v
# Out:
# Error in library(randomForest): there is no package called ‘randomForest’
# Traceback:
#
# 1. library(randomForest)

# %%
# 9.2

write.csv(prd_v, "copd_predictions.csv")
# Out:
# Error in is.data.frame(x): object 'prd_v' not found
# Traceback:
#
# 1. write.csv(prd_v, "copd_predictions.csv")
# 2. eval.parent(Call)
# 3. eval(expr, p)
# 4. eval(expr, p)
# 5. write.table(prd_v, "copd_predictions.csv", col.names = NA, sep = ",",
#  .     dec = ".", qmethod = "double")
# 6. is.data.frame(x)
